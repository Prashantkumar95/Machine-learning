# %%
import pandas as pd

# %%
dataset= pd.read_csv("Boston.csv")
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data=dataset.iloc[:,:-1]
output_data=dataset["medv"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.25)

# %%
x_test
# Out:
#      Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 326         327   0.30347  0.0   7.38     0  0.493  6.312   28.9  5.4159    5
# 225         226   0.52693  0.0   6.20     0  0.504  8.725   83.0  2.8944    8
# 211         212   0.37578  0.0  10.59     1  0.489  5.404   88.6  3.6650    4
# 96           97   0.11504  0.0   2.89     0  0.445  6.163   69.6  3.4952    2
# 492         493   0.11132  0.0  27.74     0  0.609  5.983   83.5  2.1099    4
# ..          ...       ...  ...    ...   ...    ...    ...    ...     ...  ...
# 43           44   0.15936  0.0   6.91     0  0.448  6.211    6.5  5.7209    3
# 406         407  20.71620  0.0  18.10     0  0.659  4.138  100.0  1.1781   24
# 472         473   3.56868  0.0  18.10     0  0.580  6.437   75.0  2.8965   24
# 379         380  17.86670  0.0  18.10     0  0.671  6.223  100.0  1.3861   24
# 182         183   0.09103  0.0   2.46     0  0.488  7.155   92.2  2.7006    3
#
#      tax  ptratio   black  lstat
# 326  287     19.6  396.90   6.15
# 225  307     17.4  382.00   4.63
# 211  277     18.6  395.24  23.98
# 96   276     18.0  391.83  11.34
# 492  711     20.1  396.90  13.35
# ..   ...      ...     ...    ...
# 43   233     17.9  394.46   7.44
# 406  666     20.2  370.22  23.34
# 472  666     20.2  393.37  14.36
# 379  666     20.2  393.74  21.78
# 182  193     17.8  394.12   4.82
#
# [127 rows x 14 columns]

# %%
x_train
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 409         410  14.43830   0.0  18.10     0  0.597  6.852  100.0  1.4655
# 229         230   0.44178   0.0   6.20     0  0.504  6.552   21.4  3.3751
# 266         267   0.78570  20.0   3.97     0  0.647  7.014   84.6  2.1329
# 151         152   1.49632   0.0  19.58     0  0.871  5.404  100.0  1.5916
# 186         187   0.05602   0.0   2.46     0  0.488  7.831   53.6  3.1992
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 258         259   0.66351  20.0   3.97     0  0.647  7.333  100.0  1.8946
# 460         461   4.81213   0.0  18.10     0  0.713  6.701   90.0  2.5975
# 447         448   9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980
# 338         339   0.03306   0.0   5.19     0  0.515  6.059   37.3  4.8122
# 430         431   8.49213   0.0  18.10     0  0.584  6.348   86.1  2.0527
#
#      rad  tax  ptratio   black  lstat
# 409   24  666     20.2  179.36  19.78
# 229    8  307     17.4  380.34   3.76
# 266    5  264     13.0  384.07  14.79
# 151    5  403     14.7  341.60  13.28
# 186    3  193     17.8  392.63   4.45
# ..   ...  ...      ...     ...    ...
# 258    5  264     13.0  383.29   7.79
# 460   24  666     20.2  255.23  16.42
# 447   24  666     20.2  388.52  16.44
# 338    5  224     20.2  396.14   8.51
# 430   24  666     20.2   83.45  17.64
#
# [379 rows x 14 columns]

# %%
y_test
# Out:
# 326    23.0
# 225    50.0
# 211    19.3
# 96     21.4
# 492    20.1
#        ...
# 43     24.7
# 406    11.9
# 472    23.2
# 379    10.2
# 182    37.9
# Name: medv, Length: 127, dtype: float64

# %%
y_train
# Out:
# 409    27.5
# 229    31.5
# 266    30.7
# 151    19.6
# 186    50.0
#        ...
# 258    36.0
# 460    16.4
# 447    12.6
# 338    20.6
# 430    14.5
# Name: medv, Length: 379, dtype: float64

# %%
x_train.shape, y_train.shape
# Out:
# ((379, 14), (379,))

# %%
x_test.shape,x_test.shape
# Out:
# ((127, 14), (127, 14))
