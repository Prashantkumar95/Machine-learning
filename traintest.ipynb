# %%
import pandas as pd

# %%
dataset= pd.read_csv("Boston.csv")
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data=dataset.iloc[:,:-1]
output_data=dataset["medv"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.25)

# %%
x_test
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 115         116   0.17134   0.0  10.01     0  0.547  5.928   88.2  2.4631
# 350         351   0.06211  40.0   1.25     0  0.429  6.490   44.4  8.7921
# 173         174   0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463
# 67           68   0.05789  12.5   6.07     0  0.409  5.878   21.4  6.4980
# 218         219   0.11069   0.0  13.89     1  0.550  5.951   93.8  2.8893
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 369         370   5.66998   0.0  18.10     1  0.631  6.683   96.8  1.3567
# 412         413  18.81100   0.0  18.10     0  0.597  4.628  100.0  1.5539
# 70           71   0.08826   0.0  10.81     0  0.413  6.417    6.6  5.2873
# 248         249   0.16439  22.0   5.86     0  0.431  6.433   49.1  7.8265
# 400         401  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888
#
#      rad  tax  ptratio   black  lstat
# 115    6  432     17.8  344.91  15.76
# 350    1  335     19.7  396.90   5.98
# 173    5  296     16.6  395.50   9.04
# 67     4  345     18.9  396.21   8.10
# 218    5  276     16.4  396.90  17.92
# ..   ...  ...      ...     ...    ...
# 369   24  666     20.2  375.33   3.73
# 412   24  666     20.2   28.79  34.37
# 70     4  305     19.2  383.73   6.72
# 248    7  330     19.1  374.71   9.52
# 400   24  666     20.2  396.90  26.77
#
# [127 rows x 14 columns]

# %%
x_train
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 441         442  9.72418   0.0  18.10     0  0.740  6.406  97.2  2.0651   24
# 471         472  4.03841   0.0  18.10     0  0.532  6.229  90.7  3.0993   24
# 202         203  0.02177  82.5   2.03     0  0.415  7.610  15.7  6.2700    2
# 327         328  0.24103   0.0   7.38     0  0.493  6.083  43.7  5.4159    5
# 95           96  0.12204   0.0   2.89     0  0.445  6.625  57.8  3.4952    2
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 237         238  0.51183   0.0   6.20     0  0.507  7.358  71.6  4.1480    8
# 457         458  8.20058   0.0  18.10     0  0.713  5.936  80.3  2.7792   24
# 121         122  0.07165   0.0  25.65     0  0.581  6.004  84.1  2.1974    2
# 207         208  0.25199   0.0  10.59     0  0.489  5.783  72.7  4.3549    4
# 319         320  0.47547   0.0   9.90     0  0.544  6.113  58.8  4.0019    4
#
#      tax  ptratio   black  lstat
# 441  666     20.2  385.96  19.52
# 471  666     20.2  395.33  12.87
# 202  348     14.7  395.38   3.11
# 327  287     19.6  396.90  12.79
# 95   276     18.0  357.98   6.65
# ..   ...      ...     ...    ...
# 237  307     17.4  390.07   4.73
# 457  666     20.2    3.50  16.94
# 121  188     19.1  377.67  14.27
# 207  277     18.6  389.43  18.06
# 319  304     18.4  396.23  12.73
#
# [379 rows x 14 columns]

# %%
y_test
# Out:
# 115    18.3
# 350    22.9
# 173    23.6
# 67     22.0
# 218    21.5
#        ...
# 369    50.0
# 412    17.9
# 70     24.2
# 248    24.5
# 400     5.6
# Name: medv, Length: 127, dtype: float64

# %%
y_train
# Out:
# 441    17.1
# 471    19.6
# 202    42.3
# 327    22.2
# 95     28.4
#        ...
# 237    31.5
# 457    13.5
# 121    20.3
# 207    22.5
# 319    21.0
# Name: medv, Length: 379, dtype: float64

# %%
x_train.shape, y_train.shape
# Out:
# ((379, 14), (379,))

# %%
x_test.shape,x_test.shape
# Out:
# ((127, 14), (127, 14))
